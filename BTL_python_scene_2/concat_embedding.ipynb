# %% [markdown]
# ## Trích xuất embedding mặt

# %%
import insightface
import cv2
import numpy as np
import os

# Khởi tạo mô hình InsightFace với CPU
model = insightface.app.FaceAnalysis()
model.prepare(ctx_id=-1)  # Sử dụng CPU (ctx_id=0 sẽ dùng GPU nếu có)

# Hàm trích xuất embedding của khuôn mặt từ một ảnh


def extract_face_embedding(image_path):
    img = cv2.imread(image_path)
    if img is None:
        print(f"Could not read image: {image_path}")
        return []

    # Nhận diện khuôn mặt trong ảnh
    faces = model.get(img)
    face_embeddings = []
    for face in faces:
        face_embeddings.append(face.embedding)

    return face_embeddings
# Out:
# d:\anaconda\envs\insightface_cnn\lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:54: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Dao Thi Huyen/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Dao Thi Huyen/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Dao Thi Huyen/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Dao Thi Huyen/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Dao Thi Huyen/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %% [markdown]
# ## Trích xuất embedding của cảnh

# %%
import torch
from torchvision import models, transforms
from PIL import Image
import torch.nn as nn

# Hàm trích xuất embedding của cảnh (scene) từ một ảnh


def extract_scene_embedding(image_path):
    # Đọc ảnh
    img = Image.open(image_path).convert('RGB')

    # Cấu hình tiền xử lý ảnh cho EfficientNet-B0
    preprocess = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[
                             0.229, 0.224, 0.225]),
    ])
    img_tensor = preprocess(img).unsqueeze(0)

    # Tải mô hình EfficientNet-B0 đã được huấn luyện sẵn
    model = models.efficientnet_b0(pretrained=True)
    model.classifier = nn.Identity()  # bỏ lớp phân loại
    model.eval()

    # Trích xuất đặc trưng của cảnh
    with torch.no_grad():
        scene_embedding = model(img_tensor).numpy().squeeze()

    return scene_embedding

# %% [markdown]
# ## Combine embedding face and scene

# %%
def combine_face_and_scene_embeddings(face_embeddings, scene_embedding):
    combined_embeddings = []

    for face_embedding in face_embeddings:
        # Kết hợp embedding của khuôn mặt với embedding của cảnh
        combined_embedding = np.concatenate([face_embedding, scene_embedding])
        combined_embeddings.append(combined_embedding)

    return np.array(combined_embeddings)

# %% [markdown]
# ## Save combine_embeddings

# %%
# %pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.9.0.post1-cp39-cp39-win_amd64.whl.metadata (4.5 kB)
# Collecting numpy<3.0,>=1.25.0 (from faiss-cpu)
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: packaging in d:\anaconda\envs\insightface\lib\site-packages (from faiss-cpu) (24.1)
# Downloading faiss_cpu-1.9.0.post1-cp39-cp39-win_amd64.whl (13.8 MB)
#    ---------------------------------------- 0.0/13.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.8 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/13.8 MB 5.9 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/13.8 MB 5.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.9/13.8 MB 5.7 MB/s eta 0:00:02
#    ------------ --------------------------- 4.5/13.8 MB 4.8 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.8 MB 4.3 MB/s eta 0:00:03
#    --------------- ------------------------ 5.2/13.8 MB 3.8 MB/s eta 0:00:03
#    ---------------- ----------------------- 5.8/13.8 MB 3.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 6.0/13.8 MB 3.4 MB/s eta 0:00:03
#    ------------------ --------------------- 6.6/13.8 MB 3.2 MB/s eta 0:00:03
#    -------------------- ------------------- 7.1/13.8 MB 3.1 MB/s eta 0:00:03
#    --------------------- ------------------ 7.6/13.8 MB 3.1 MB/s eta 0:00:03
#    ---------------------- ----------------- 7.9/13.8 MB 3.0 MB/s eta 0:00:02
#    ------------------------ --------------- 8.4/13.8 MB 3.0 MB/s eta 0:00:02
#    ------------------------- -------------- 8.9/13.8 MB 2.9 MB/s eta 0:00:02
#    --------------------------- ------------ 9.4/13.8 MB 2.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 10.0/13.8 MB 2.9 MB/s eta 0:00:02
#    ------------------------------ --------- 10.5/13.8 MB 2.8 MB/s eta 0:00:02
#    ------------------------------- -------- 11.0/13.8 MB 2.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 11.8/13.8 MB 2.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.3/13.8 MB 2.8 MB/s eta 0:00:01
#    ------------------------------------- -- 12.8/13.8 MB 2.8 MB/s eta 0:00:01
#    -------------------------------------- - 13.4/13.8 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.8/13.8 MB 2.8 MB/s eta 0:00:00
# Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# Installing collected packages: numpy, faiss-cpu
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Successfully installed faiss-cpu-1.9.0.post1 numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import json


def process_images_in_folder(image_folder, scene_folder):
    all_combined_embeddings = []
    metadata = []

    for imdb_id in os.listdir(image_folder):
        print(f"đang xử lý phim {imdb_id}")
        movie_folder = os.path.join(image_folder, imdb_id)
        scene_movie_folder = os.path.join(scene_folder, imdb_id)

        if os.path.isdir(movie_folder) and os.path.isdir(scene_movie_folder):
            # Trích xuất embedding khuôn mặt

            for image_name in os.listdir(movie_folder):
                image_path = os.path.join(movie_folder, image_name)
                scene_image_path = os.path.join(scene_movie_folder, image_name)

                face_embeddings = extract_face_embedding(image_path)
                scene_embedding = extract_scene_embedding(scene_image_path)
                combine_embeddings = combine_face_and_scene_embeddings(
                    face_embeddings, scene_embedding)
                all_combined_embeddings.extend(combine_embeddings)

                for _ in combine_embeddings:
                    metadata.append({
                        'imdb_id': imdb_id,
                        'image_name': image_name,
                    })

    # Lưu metadata vào file JSON
    with open('metadata.json', 'w') as jsonfile:
        json.dump(metadata, jsonfile)
    return np.array(all_combined_embeddings)

# %%
all_combined_embeddings = process_images_in_folder(
    'image5_2', 'image5_scene')
# Out:
# đang xử lý phim 0068646
# d:\anaconda\envs\InsightFace\lib\site-packages\insightface\utils\transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# d:\anaconda\envs\InsightFace\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\anaconda\envs\InsightFace\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# đang xử lý phim 0119217
# đang xử lý phim 0120082
# đang xử lý phim 0120338
# đang xử lý phim 0167260
# đang xử lý phim 0264235
# đang xử lý phim 0285331
# đang xử lý phim 0285333
# đang xử lý phim 0367279
# đang xử lý phim 0372784
# đang xử lý phim 0381061
# đang xử lý phim 0407887
# đang xử lý phim 0468569
# đang xử lý phim 0780504
# đang xử lý phim 0816692
# đang xử lý phim 0848228
# đang xử lý phim 0993846
# đang xử lý phim 10155688
# đang xử lý phim 10640346
# đang xử lý phim 10648342
# đang xử lý phim 1104001
# đang xử lý phim 12037194
# đang xử lý phim 12361974
# đang xử lý phim 1345836
# đang xử lý phim 1386697
# đang xử lý phim 1392190
# đang xử lý phim 1502407
# đang xử lý phim 1517268
# đang xử lý phim 1570728
# đang xử lý phim 1596363
# đang xử lý phim 1655389
# đang xử lý phim 1706620
# đang xử lý phim 1707386
# đang xử lý phim 1837576
# đang xử lý phim 1856101
# đang xử lý phim 2015381
# đang xử lý phim 2304589
# đang xử lý phim 2356777
# đang xử lý phim 2382320
# đang xử lý phim 2488496
# đang xử lý phim 2584384
# đang xử lý phim 2935510
# đang xử lý phim 3032476
# đang xử lý phim 3205802
# đang xử lý phim 3480822
# đang xử lý phim 3498820
# đang xử lý phim 3501632
# đang xử lý phim 4154664
# đang xử lý phim 4154756
# đang xử lý phim 4154796
# đang xử lý phim 4236770
# đang xử lý phim 5071412
# đang xử lý phim 5114356
# đang xử lý phim 5537002
# đang xử lý phim 6263850
# đang xử lý phim 6264654
# đang xử lý phim 6334354
# đang xử lý phim 6394270
# đang xử lý phim 7221388
# đang xử lý phim 7653254
# đang xử lý phim 7660850
# đang xử lý phim 7713068
# đang xử lý phim 7888964
# đang xử lý phim 8367814
# đang xử lý phim 9140554

# %%
print(all_combined_embeddings.shape)
# Out:
# (19008, 1792)

# %%
np.save('all_combined_embeddings.npy', all_combined_embeddings)

# %% [markdown]
# ## Lưu combine embedding tập test

# %%
import json


def process_images_in_folder_test(image_folder, scene_folder):
    all_combined_embeddings = []
    metadata = []

    for imdb_id in os.listdir(image_folder):
        print(f"đang xử lý phim {imdb_id}")
        movie_folder = os.path.join(image_folder, imdb_id)
        scene_movie_folder = os.path.join(scene_folder, imdb_id)

        if os.path.isdir(movie_folder) and os.path.isdir(scene_movie_folder):
            # Trích xuất embedding khuôn mặt

            for image_name in os.listdir(movie_folder):
                image_path = os.path.join(movie_folder, image_name)
                scene_image_path = os.path.join(scene_movie_folder, image_name)

                face_embeddings = extract_face_embedding(image_path)
                scene_embedding = extract_scene_embedding(scene_image_path)
                combine_embeddings = combine_face_and_scene_embeddings(
                    face_embeddings, scene_embedding)
                all_combined_embeddings.append(
                    combine_embeddings)    # sửa extend thành append

                metadata.append({
                    'imdb_id': imdb_id,
                    'image_name': image_name,
                })

    # Lưu metadata vào file JSON
    with open('metadata_test.json', 'w') as jsonfile:
        json.dump(metadata, jsonfile)
    return np.array(all_combined_embeddings, dtype=object)

# %%
test_all_combined_embeddings = process_images_in_folder_test(
    'image_val', 'image_val_scene')
# Out:
# đang xử lý phim 0068646
# d:\anaconda\envs\InsightFace\lib\site-packages\insightface\utils\transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# d:\anaconda\envs\InsightFace\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# d:\anaconda\envs\InsightFace\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# đang xử lý phim 0119217
# đang xử lý phim 0120082
# đang xử lý phim 0120338
# đang xử lý phim 0167260
# đang xử lý phim 0264235
# đang xử lý phim 0285331
# đang xử lý phim 0285333
# đang xử lý phim 0367279
# đang xử lý phim 0372784
# đang xử lý phim 0381061
# đang xử lý phim 0407887
# đang xử lý phim 0468569
# đang xử lý phim 0780504
# đang xử lý phim 0816692
# đang xử lý phim 0848228
# đang xử lý phim 0993846
# đang xử lý phim 10155688
# đang xử lý phim 10640346
# đang xử lý phim 10648342
# đang xử lý phim 1104001
# đang xử lý phim 12037194
# đang xử lý phim 12361974
# đang xử lý phim 1345836
# đang xử lý phim 1386697
# đang xử lý phim 1392190
# đang xử lý phim 1502407
# đang xử lý phim 1517268
# đang xử lý phim 1570728
# đang xử lý phim 1596363
# đang xử lý phim 1655389
# đang xử lý phim 1706620
# đang xử lý phim 1707386
# đang xử lý phim 1837576
# đang xử lý phim 1856101
# đang xử lý phim 2015381
# đang xử lý phim 2304589
# đang xử lý phim 2356777
# đang xử lý phim 2382320
# đang xử lý phim 2488496
# đang xử lý phim 2584384
# đang xử lý phim 2935510
# đang xử lý phim 3032476
# đang xử lý phim 3205802
# đang xử lý phim 3480822
# đang xử lý phim 3498820
# đang xử lý phim 3501632
# đang xử lý phim 4154664
# đang xử lý phim 4154756
# đang xử lý phim 4154796
# đang xử lý phim 4236770
# đang xử lý phim 5071412
# đang xử lý phim 5114356
# đang xử lý phim 5537002
# đang xử lý phim 6263850
# đang xử lý phim 6264654
# đang xử lý phim 6334354
# đang xử lý phim 6394270
# đang xử lý phim 7221388
# đang xử lý phim 7653254
# đang xử lý phim 7660850
# đang xử lý phim 7713068
# đang xử lý phim 7888964
# đang xử lý phim 8367814
# đang xử lý phim 9140554

# %%
print(test_all_combined_embeddings.shape)
print(test_all_combined_embeddings[6].shape)
# Out:
# (1998,)
# (3, 1792)

# %%
print(np.linalg.norm(test_all_combined_embeddings[0][0]))
# Out:
# 28.41461

# %%
np.save('test_all_combinecombine_embeddings.npy', test_all_combined_embeddings)

# %% [markdown]
# ## truy vấn 10 ảnh giống ảnh test

# %%
import json

# Đọc metadata từ file JSON
with open('metadata.json', 'r') as jsonfile:
    metadata = json.load(jsonfile)


# Đọc lại embeddings từ file .npy
all_combined_embeddings = np.load('all_combined_embeddings.npy')

# %%
with open('metadata_test.json', 'r') as jsonfile2:
    metadata_test = json.load(jsonfile2)

test_all_combined_embeddings = np.load(
    'test_all_combinecombine_embeddings.npy', allow_pickle=True)

# %%
import numpy as np
import json
import os
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity


def find_top_similar_images(query_vectors, all_embeddings, metadata, top_n=10):
    # Lưu danh sách top kết quả từ tất cả query_vector
    all_top_results = []

    for q_vec in query_vectors:
        # Tính cosine similarity
        similarities = cosine_similarity([q_vec], all_embeddings)[0]

        # Lấy chỉ số của top N vector tốt nhất
        top_indices = np.argsort(similarities)[::-1][:top_n]

        # Lưu cả chỉ số và độ tương tự
        for idx in top_indices:
            all_top_results.append((idx, similarities[idx]))

    # Sắp xếp toàn bộ danh sách theo cosine similarity giảm dần
    all_top_results = sorted(all_top_results, key=lambda x: x[1], reverse=True)

    # Lấy top N tốt nhất từ danh sách tổng hợp
    final_top_n = all_top_results[:top_n]

    # Tách chỉ số và cosine similarity
    top_indices = [idx for idx, _ in final_top_n]

    # Lấy thông tin metadata tương ứng
    top_metadata = [metadata[i] for i in top_indices]
    imdb_ids = [meta["imdb_id"] for meta in top_metadata]
    predict_id = max(set(imdb_ids), key=imdb_ids.count)

    return predict_id

# %%
import os
import shutil


def save_false_image(metadata_test, idx, image_folder, false_image_folder):
    # Lấy thông tin về ảnh từ metadata_test
    imdb_id = metadata_test[idx]["imdb_id"]
    image_name = metadata_test[idx]["image_name"]
    image_path = os.path.join(image_folder, imdb_id, image_name)

    if os.path.exists(image_path):
        # Tạo thư mục cho ảnh sai (false_image) nếu chưa tồn tại
        false_image_dir = os.path.join(false_image_folder, imdb_id)
        if not os.path.exists(false_image_dir):
            os.makedirs(false_image_dir)

        # Sao chép ảnh vào thư mục false_image
        shutil.copy(image_path, os.path.join(false_image_dir, image_name))
        print(f"Image {image_name} saved to {false_image_dir}")
    else:
        print(f"Image {image_name} not found in {image_path}")

# %%
def calculate_accuracy(test_all_combined_embeddings, all_embeddings, metadata, metadata_test, top_n=10):
    correct_predictions = 0

    for idx, query_vector in enumerate(test_all_combined_embeddings):
        # Gọi hàm find_top_similar_images để lấy top N vecto giống nhất và dự đoán
        predict_id = find_top_similar_images(
            query_vector, all_embeddings, metadata, top_n)

        # So sánh với imdb_id thực tế từ metadata_test
        true_id = metadata_test[idx]["imdb_id"]
        if predict_id == true_id:
            correct_predictions += 1
        else:
            save_false_image(metadata_test, idx, 'image_val', 'false_image')

    # Tính độ chính xác (accuracy)
    accuracy = correct_predictions / len(test_all_combined_embeddings)
    return accuracy

# %%
accuracy = calculate_accuracy(test_all_combined_embeddings,
                              all_combined_embeddings, metadata, metadata_test, top_n=10)

# In kết quả
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Image Al_Pacino_MV5BZDcwODg5ODYtZjhjOC00ZDcwLWFkN2EtYzMyZDVhM2JmZDE0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0068646
# Image Marlon_Brando_Al_Pacino_MV5BNWY3NTRiODMtOTdmZS00MDcyLWE5NDItOTM1YjAzNTgyYTlmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0068646
# Image Marlon_Brando_James_Caan_MV5BNzAxNWU2ZDMtMzZmMC00NWQ0LWEyMzItNmE2ZjEzOTc4MjZiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0068646
# Image Marlon_Brando_MV5BMTI3MzI3MTcwOV5BMl5BanBnXkFtZTYwNjk5MDI2._V1_QL75_UX2000_.jpg saved to false_image\0068646
# Image Marlon_Brando_MV5BMTIzNDY0NTEyMF5BMl5BanBnXkFtZTYwODM0NTQ2._V1_QL75_UX2000_.jpg saved to false_image\0068646
# Image Leonardo_DiCaprio_Kate_Winslet_MV5BMjA1MDQyODU4Nl5BMl5BanBnXkFtZTcwMTc2NTk1Nw@@._V1_QL75_UX2000_.jpg saved to false_image\0120338
# Image Leonardo_DiCaprio_Kate_Winslet_MV5BZDRjNTI1MmQtMzIxMy00MDkyLWEzZjktNmI5MWI0N2I1ZGZmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0120338
# Image Cheryl_Hines_MV5BMTllZThiOWMtZjFjMC00MzA5LThmNTQtMjU0YjM5NzhiZTk3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0264235
# Image Larry_David_Cheryl_Hines_MV5BMjRkZjUxYTYtM2JmMy00Zjc1LTk0ZTgtNDNlMDgyOTJkY2U0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0264235
# Image Larry_David_Jeff_Garlin_MV5BNWNiZjY5ODEtMjUxZi00NGIxLTk2OTQtZmEwNzdhYjM4MzEzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0264235
# Image Larry_David_MV5BNTg5ZTFkN2ItNjBiZi00YTc5LWE0ZTEtNDhjYjYwYTIzMjM4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0264235
# Image Kiefer_Sutherland_Carlos_Bernard_MV5BMjA4NjY0NzcwOV5BMl5BanBnXkFtZTcwMzE1OTIxMw@@._V1_QL75_UX2000_.jpg saved to false_image\0285331
# Image Kiefer_Sutherland_MV5BMTQzMTI1MDA1OF5BMl5BanBnXkFtZTcwMDM2NjA1Mw@@._V1_QL75_UX2000_.jpg saved to false_image\0285331
# Image Jennifer_Garner_MV5BMjE0NzMyMjY5NF5BMl5BanBnXkFtZTgwNTUwMDgzMjE@._V1_QL75_UX2000_.jpg saved to false_image\0285333
# Image Jennifer_Garner_MV5BMjU5NjM5NTc2NF5BMl5BanBnXkFtZTgwMjAxMDgzMjE@._V1_QL75_UX2000_.jpg saved to false_image\0285333
# Image Jennifer_Garner_MV5BMTg2MTExMzA2OV5BMl5BanBnXkFtZTgwODM5OTczMjE@._V1_QL75_UX2000_.jpg saved to false_image\0285333
# Image Jennifer_Garner_MV5BODAxODc3NDc4N15BMl5BanBnXkFtZTgwNzU5OTEwMjE@._V1_QL75_UX2000_.jpg saved to false_image\0285333
# Image Jennifer_Garner_MV5BODM1ODE2MDUzNF5BMl5BanBnXkFtZTgwMDQwMDgzMjE@._V1_QL75_UX2000_.jpg saved to false_image\0285333
# Image Portia_de_Rossi_MV5BMTQ0NTU1NzAyNl5BMl5BanBnXkFtZTcwMzUxODk1OQ@@._V1_QL75_UX2000_.jpg saved to false_image\0367279
# Image Christian_Bale_Liam_Neeson_MV5BMTY4YWU1NDMtMDg4YS00YTc5LWFmYTItMDg1MzJlOWZhZTIzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_Liam_Neeson_MV5BYWRmMjU3MjEtZjZlMS00YjdjLWE4ZTgtZmM5YTUzMDlkNzZjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_MV5BMjE1MDQ4NzIyN15BMl5BanBnXkFtZTcwMTA5OTIyNw@@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_MV5BMTI3NDMyMTMzOF5BMl5BanBnXkFtZTYwNjkwMTI3._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_MV5BNTg4MDg0ODQyNl5BMl5BanBnXkFtZTcwNDYwODc3Mw@@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_MV5BZGQ4YzMwNzItMmFlYS00M2FjLTkzNTAtZTY5ZGI3MDFmNzUyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Christian_Bale_MV5BZWQ5NjcyZDMtMzEyNi00ODM3LWJiMWUtZWRhYTYyNzNjOTA3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Michael_Caine_MV5BOTkxZTE3OTQtMmNmZi00NzljLTljNDctY2U5YjhiOTFjNjMzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0372784
# Image Daniel_Craig_MV5BMTIzMDQ4NjgyOV5BMl5BanBnXkFtZTcwNTkxNDU5MQ@@._V1_QL75_UX2000_.jpg saved to false_image\0381061
# Image Daniel_Craig_MV5BYjhhODc4YzctMWM4Ni00MTUwLWFmOGItZTI4YjllYjAxY2JiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0381061
# Image Jack_Nicholson_MV5BYmFjZjQzYWMtNDZkNS00NTI1LThmZDctOWI4ZWNlZWIwMGI4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Leonardo_DiCaprio_MV5BM2U3N2Y1MzctNzUwOC00OWM3LTk0YTUtZjZmMWE5MmNhNzVjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Leonardo_DiCaprio_MV5BMjQ2MzVhOWQtOTU2Ny00NWQ1LTg1ZTYtMGYyODgxYTg4Y2NiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Leonardo_DiCaprio_MV5BMWNmMmEwZGItMmYzYy00NmMzLTlmYjktZTlmOThjNWFhYzU4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Leonardo_DiCaprio_MV5BNGQ2MzI1M2QtMWMwMi00MGIzLTgzYTYtODA4YWFmNDBiZWE4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Leonardo_DiCaprio_MV5BYjNjY2FiZGQtOWNjMy00OTIzLWIwOWMtYjJjNzIxZTRmZjYzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0407887
# Image Aaron_Eckhart_MV5BYTk5ZmE0NjQtNjIxNy00ZmNmLWJmMWYtOTZmYThhMTBlZDRiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Christian_Bale_Michael_Caine_MV5BZmQwYTcyYWUtYmRkNy00NTE3LWExOTMtM2I2Njc5MGQ0MDgzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Christian_Bale_MV5BMjIyMzI3MTk0Nl5BMl5BanBnXkFtZTcwODYxMTk2Mw@@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Christian_Bale_MV5BYTY3MTJiNzctZGQ1OS00OGJjLTgzOWUtZjE5MDJkMDcwMDA3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Christian_Bale_MV5BYWZkNzNhNzgtYzY0Yy00NTlhLTk2NTYtNGVmZmQyMTJjNmRkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Christian_Bale_MV5BZTVlZjg5ZWMtOWM3Ni00ZGE1LWE0MGEtYjAzYzEzODhjNzU2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Michael_Caine_MV5BODQyOGFiMDUtNWU4OC00ZWVjLTk5MTktOGU0YjgyOTI5Yzc3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0468569
# Image Chris_Evans_MV5BMjA3OTU3ODc3MV5BMl5BanBnXkFtZTcwNzUxNDY1Nw@@._V1_QL75_UX2000_.jpg saved to false_image\0848228
# Image Chris_Evans_MV5BMjU0MTgxMjE1Nl5BMl5BanBnXkFtZTcwNDA4MDg4Ng@@._V1_QL75_UX2000_.jpg saved to false_image\0848228
# Image Robert_Downey_Jr._Chris_Evans_MV5BMjMxNjY2OTc2Ml5BMl5BanBnXkFtZTcwMjA5ODY3Nw@@._V1_QL75_UX2000_.jpg saved to false_image\0848228
# Image Robert_Downey_Jr._Chris_Evans_Scarlett_Johansson_Jeremy_Renner_MV5BZmQ5Y2U3YTMtMTA0MS00NzFmLWExODItMzEwOWY0NDM2MGZiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\0848228
# Image Angourie_Rice_MV5BMThhNjY0ZTYtMDQzZC00MmZkLWJjN2QtNmMwZGIyOWJiZGRmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10155688
# Image Julianne_Nicholson_MV5BYTUwNzA3Y2YtMjA5Ny00ZTg3LWE4YTYtMjc5Nzk0NGJhZTE4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10155688
# Image Brad_Pitt_MV5BZDNkYzljMzgtOTQxYS00YmRlLWEwNGYtZjQ3Y2EzYjQxOWE1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10640346
# Image Brad_Pitt_Olivia_Wilde_MV5BZjI1ZWIxNDctMWE4Yi00OWU2LTliZTQtMjhjODAyYTYyYjYwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10640346
# Image Margot_Robbie_MV5BMzE4OWU1ZDMtOWVlMC00ZmM2LWFmY2UtODFjZDhkZjkyZjY3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10640346
# Image Chris_Hemsworth_Christian_Bale_MV5BYzJiNDFlOWQtMzU5Zi00NDAwLTg2NmQtNWFkOGJkOTcyZTBmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10648342
# Image Chris_Hemsworth_MV5BNGQzMzVjNzItZjEzYS00MTM5LWI3ZDQtYzQzY2UwOWU0MzgzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10648342
# Image Natalie_Portman_MV5BYTE0NjBjNmUtMmQ1Zi00YWFjLWFkZjEtYjdiZWUxNjYyZGQ2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\10648342
# Image Garrett_Hedlund_Olivia_Wilde_MV5BNDgzMTExMzE1M15BMl5BanBnXkFtZTcwMjk1NTM4NA@@._V1_QL75_UX2000_.jpg saved to false_image\1104001
# Image Jeff_Bridges_Garrett_Hedlund_MV5BMTQ5MTMwNzk2N15BMl5BanBnXkFtZTcwNDUzNjM4NA@@._V1_QL75_UX2000_.jpg saved to false_image\1104001
# Image Chris_Hemsworth_MV5BNGI5MmQzZDMtMTAxYi00NGI2LTgzMmItMTliOGJhYTU5ZDM0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\12037194
# Image Ben_Affleck_MV5BZGM2NjhlZGYtNDcwYS00MjZjLWFkY2UtMDBiOTdiOGI4NmNiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\12361974
# Image Henry_Cavill_MV5BZmQ1MzYyMGQtZGYzZS00YTQ2LTk0NTUtNjE4Mzg1YTc2NzQ4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\12361974
# Image Anne_Hathaway_MV5BNWQ4ZTVkOGUtODhkYy00NWFhLWE1M2ItMGZmNjJiYzg2YmE4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Anne_Hathaway_MV5BYjI5YjZhNmMtZTliMy00YWE1LWJiNDEtZjE5ZTIzNzZmODNiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Anne_Hathaway_MV5BZDdkYmRkMjQtYTNhZS00MzhmLTliMjItNzEwMWZiZGY0NDYwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Anne_Hathaway_MV5BZGFjYTZlODYtMjRiYi00NTFjLTllYzgtNjU5Yjk5OWQwOGRhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Anne_Hathaway_MV5BZmEyY2U4ODEtN2I3My00ZjNmLTgxYjktYzNhODQ5NjRlMGRkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_MV5BMTdhZDMxOGItMzg5ZC00NTJkLThjNGItMTM0NDUzNjkxOTRkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_MV5BMTY5MTUxZDMtZTA4Zi00NmI5LTk0ZDYtYTllNTJlZGMwMGNjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_MV5BOGMwNDQxMGYtY2UxMC00NTk5LWI1ODgtNzEzYTUxMzk4NDI0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_Tom_Hardy_MV5BMjA0NzMxMDUyNl5BMl5BanBnXkFtZTcwMTU2OTcxNw@@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_Tom_Hardy_MV5BNmIxNjcyODMtNjczNS00YjE3LThkNDQtZjIxMzgxNzMwYjk2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Christian_Bale_Tom_Hardy_MV5BYzQwMjU5ZTQtYTJmMS00YzE0LThkYjEtNGQ5MzFmYTVjZDlkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Tom_Hardy_MV5BNjY1NTQxMDE0OV5BMl5BanBnXkFtZTcwMTU5ODgwOA@@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Tom_Hardy_MV5BOWRhZGVjOWQtYTBlMy00YzM3LWE1YmQtMTMxOWJjM2I1ODdmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1345836
# Image Margot_Robbie_MV5BOTFkMDUyOTMtMjc1MC00MmVkLTg2ZDAtMTM2NmJiOTYxNWNmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1386697
# Image Viola_Davis_MV5BMDFlMWFhMGUtYTZjNi00ODdiLTk0NDctYjAzZDlkMDZkYzkzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1386697
# Image Viola_Davis_MV5BNDNmYmIyMTYtZGE3Ni00MTM3LWIwMTYtMzk0MTZmOTExYWI2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1386697
# Image Viola_Davis_MV5BZDE2Y2I2OWEtNTUxNi00MjJkLWFkNjItZDhmYzZiMGI0NzZlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1386697
# Image Will_Smith_MV5BYzU0MzJkMzYtMTQwNC00OGFjLWFjZDItMGQ4ZTRjMTIxZWE0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1386697
# Image Charlize_Theron_MV5BM2RlMGM2ODItM2E2NC00YWFhLTg4NjQtNWU0MzlkMDhkNTBiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1392190
# Image Charlize_Theron_MV5BOWYxZTI4M2QtNWY4OC00NzZiLWI2M2YtYzNjMzkzOGRlYTY0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1392190
# Image Tom_Hardy_MV5BODJhOTM3ODktODAzMC00ODgxLWIxZDAtZjc0ZDE3ZjMzYTkxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1392190
# Image James_Jude_Courtney_MV5BZTJlN2VkZGEtMTgzMC00N2ZmLWEyMDMtODM2NjY2NjZhOGViXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1502407
# Image Jamie_Lee_Curtis_MV5BOTIxMTU1ZjctNzBkYS00Njg4LWIyNTYtODQ2MDEyY2RiN2MyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1502407
# Image Jamie_Lee_Curtis_MV5BYjc2NGZlMjctN2RlNi00ZGVjLWI0NjQtYzA3ZTU3ZTc3YjFmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1502407
# Image Margot_Robbie_MV5BNDU0MWRhZGQtOTYzOS00M2FkLWIxYTAtZDgwYzRlNmNjNzI3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1517268
# Image Margot_Robbie_Ryan_Gosling_MV5BNWJkZTk5MzEtZGFjNC00YzQxLWFmYWQtNTQzZDJhMjk2NjRkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1517268
# Image Ryan_Gosling_MV5BYTk5YzQ3YzMtYzIyNS00NDA2LThlOTItOWExYmU3YjI3OTY1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1517268
# Image Emma_Stone_MV5BNzM4NTYyMDEyMl5BMl5BanBnXkFtZTcwMDI2MjU5NQ@@._V1_QL75_UX2000_.jpg saved to false_image\1570728
# Image Ryan_Gosling_Emma_Stone_MV5BYThhOGI1YjYtOGUwNi00MzdkLTllMmUtZWFhM2VlMzg1N2EwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1570728
# Image Christian_Bale_MV5BMTUwMTAwODEzNF5BMl5BanBnXkFtZTgwNjQ5NzM0NzE@._V1_QL75_UX2000_.jpg saved to false_image\1596363
# Image Steve_Carell_MV5BNmM0YjJmY2QtNjVlZi00NDAyLTgwYTgtOTFkMTYwNTc2NzE3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1596363
# Image Chris_Evans_Jamie_Bell_MV5BYjVkOGQ3NjctNGFmZC00OWYxLTliODktMmQyZGIwYWMwNWIyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1706620
# Image Chris_Evans_MV5BODI1Y2E0ODQtNGQ0Zi00OTRmLWFkZmItNDFhNTEyODFmMjlmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1706620
# Image Anne_Hathaway_MV5BYTllNjMxYzktMjc5Yi00YThjLThhNjEtZWYzODQ3NzcxNDYxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1707386
# Image Hugh_Jackman_Amanda_Seyfried_MV5BNGU1YmRhNWItMjViZS00MTMwLWJiZjUtN2Y4NDFmNDM1YTFhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1707386
# Image Russell_Crowe_MV5BNzVhMjFkZDQtYmI5NS00NGU2LWIzZGUtMWZjMmFiZTNjNjg5XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1707386
# Image Ana_de_Armas_MV5BY2FjMTgzNjctMDM4NS00YmZmLTg2MzUtYzhjMjk4YzJlMzI4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1856101
# Image Harrison_Ford_MV5BMWVhMGRkNTctNzllMi00YTkyLTlmOGMtYmMzNGY4YzQ1YWMwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1856101
# Image Harrison_Ford_MV5BYTllMWEyMTYtZjBhMC00ODg5LWE3ZDAtZDFkZjhhNGEzNjk0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1856101
# Image Harrison_Ford_Ryan_Gosling_MV5BMThiZWM5MzYtZDc4OC00M2YzLTg1NDUtYmQxMWI5Y2EyZjEwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1856101
# Image Ryan_Gosling_Ana_de_Armas_MV5BZTM1OGMxZGYtNzNmYS00MTFkLTgzMjItMTAzNjIxODUxMjZjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\1856101
# Image Chris_Pratt_Bradley_Cooper_Zoe_Saldana_MV5BZGU0MGNmMmEtYWJmZi00OTEzLWEwNzQtOTEyMDIwMDFjMWVlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2015381
# Image Vin_Diesel_Bradley_Cooper_MV5BNDc4ZDJmOTQtYjA0MC00YzBjLWE4YTUtZjA3ZTI1YzEwNTg2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2015381
# Image Chris_Evans_Cherry_Jones_MV5BNDAyZDQ1MmYtOGUxMy00OGIwLWJjNTMtMjA2ODQ5NWNjMjhjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2304589
# Image Vince_Vaughn_MV5BNjE4MmIyNzYtNjQ4MS00ZDVmLTg2ZTMtNmJmODVhYmQyMmZjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2356777
# Image Daisy_Ridley_John_Boyega_Oscar_Isaac_Domhnall_Gleeson_MV5BNzA0MjY5MjMyNl5BMl5BanBnXkFtZTgwMzQwOTk2MTE@._V1_QL75_UX2000_.jpg saved to false_image\2488496
# Image John_Boyega_MV5BMjM5NWE0OGMtYTgxMC00YTA0LWIyZjUtMzk3MzYwMGFjZmI3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2488496
# Image Roman_Griffin_Davis_MV5BZTNhN2VkYTMtNDA5YS00YWU3LWI4NzYtNWVjNGQ3NjNiZjJkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Roman_Griffin_Davis_Scarlett_Johansson_MV5BYTcwOTg0YjEtMTIzYi00NzMxLWJjOTQtYWRiM2ZjMjA4MDhlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Taika_Waititi_MV5BM2JiNmM3MDYtMmJhYy00OGM5LThmZjQtY2JlYmI3YjcwODJhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Taika_Waititi_MV5BMGUxY2VlNjMtZDgzOS00OTNlLWJiMzAtNzYzZTU1YzdjYjYyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Taika_Waititi_MV5BOTIyN2FmMWItYzg2ZS00MGRlLTllMjUtMzk1OGZkYmYzMGE4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Taika_Waititi_MV5BYTBiODljZGMtYTg4NS00YjhlLWJkODctODQ1ODM0NjNkYjYyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2584384
# Image Brad_Pitt_MV5BNzg2ZDUyY2YtODQwZS00YjFhLWE1ZmItMWM2MWRhZTM3YmJhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2935510
# Image Brad_Pitt_MV5BOGI0MjZlMzktNDcyMi00OGNlLTk5NjgtNDc0MDcyMTcxMmY2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\2935510
# Image Jonathan_Banks_MV5BMjIxNTU2NzU0OF5BMl5BanBnXkFtZTgwNjY2ODIzODE@._V1_QL75_UX2000_.jpg saved to false_image\3032476
# Image Jonathan_Banks_MV5BMTcyMjI0OTI5NV5BMl5BanBnXkFtZTgwMjc1ODIzODE@._V1_QL75_UX2000_.jpg saved to false_image\3032476
# Image Jonathan_Banks_MV5BMTk5NDY5Mzc2M15BMl5BanBnXkFtZTgwMTYwNzYzODE@._V1_QL75_UX2000_.jpg saved to false_image\3032476
# Image Jonathan_Banks_MV5BMTUwMDE4ODQwM15BMl5BanBnXkFtZTgwNzY4MDY2ODE@._V1_QL75_UX2000_.jpg saved to false_image\3032476
# Image Scarlett_Johansson_MV5BZGZmY2E0MGItNTkzNS00MmVmLTg0ODctODUxNWZiODk1NzNiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3480822
# Image Chris_Evans_MV5BNzE2MDMzNDA4Ml5BMl5BanBnXkFtZTgwMjg5ODEyODE@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Chris_Evans_MV5BOWRiOGFkNWUtZWM5MC00OTU3LThmNzgtMzliNjQxNmFkODgzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Chris_Evans_MV5BYTNjNjMwYWYtNDc4ZC00ZTk2LWEyNDMtZDBkNmQ0Yzc5MDA4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Robert_Downey_Jr._MV5BODQxYzIxMzctNzkxYS00MGRhLWJhMzAtMjNjMGNkMzZlYWQ3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Scarlett_Johansson_MV5BN2Y5NjkzMzAtYTI2My00YmI5LTkyODgtOWJiNjBmZTc0NmJmXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Scarlett_Johansson_MV5BZTQ3OTE3ODgtZGNiNy00NmI1LThkZWQtYjQ1MWEyYjZlNzQ2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Scarlett_Johansson_MV5BZWE5NTc3ODktZWVmNC00ZDMxLTkxYjAtZmJkNDQ0ZDdmNWQ5XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Sebastian_Stan_MV5BMGY4NmZkYzEtMzMwYi00NGY4LTkwOTQtODIzYWVlNjM2MDJjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Sebastian_Stan_MV5BNTQ0ZWQxMzYtNGVjZC00YTNkLWIzNWQtM2Y0MTFjMzA1M2E4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Sebastian_Stan_MV5BYzVhMWE1N2EtN2YzOS00ZTMzLWE5MmQtNTk0ZGY5YjAwZjFiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3498820
# Image Cate_Blanchett_MV5BODA4NDQ5MzI3Nl5BMl5BanBnXkFtZTgwODI2MTgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_MV5BMjQzMjE2MTQyOV5BMl5BanBnXkFtZTgwMTM2MTgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_MV5BMTg4MDM1Mzg3OF5BMl5BanBnXkFtZTgwMzMyMjgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_MV5BMTgzMzU1OTAzN15BMl5BanBnXkFtZTgwMjIyMjgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_MV5BMTUxMjk5MTg5NV5BMl5BanBnXkFtZTgwNTIyMjgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_MV5BMTY3NTM5ODg0M15BMl5BanBnXkFtZTgwMjM2MTgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_Tom_Hiddleston_MV5BMGY4NTc2MDEtN2JjYS00MmNkLTkzOGMtYzY2MTQwZjdkY2Q1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_Tom_Hiddleston_MV5BMTUxNTc4OTE4NV5BMl5BanBnXkFtZTgwOTIyMjgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Chris_Hemsworth_Tom_Hiddleston_MV5BYzI5ODc3MWMtNzU5Yi00NjdkLWIxOWUtN2Y5MjI0YzJhZmRlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Mark_Ruffalo_MV5BMzU0YTI1NWQtMDNlMy00ZTMzLTg5YmMtMmMzMmYxNjlmOTJiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Mark_Ruffalo_MV5BOTI5MjMyMDIxMF5BMl5BanBnXkFtZTgwODAxMjgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Tom_Hiddleston_MV5BMTg1OTYyNzYyNF5BMl5BanBnXkFtZTgwNTM2MTgwNDI@._V1_QL75_UX2000_.jpg saved to false_image\3501632
# Image Brie_Larson_MV5BNmJlODcwMjMtMjhmNC00OTdlLTk3ZDUtYWY4MmQyMjcxZjgyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154664
# Image Brie_Larson_Samuel_L._Jackson_MV5BNDI4NTcxNDYtODRiZS00YmQ0LTkzMmQtZGVkN2FkNjk4NjIyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154664
# Image Samuel_L._Jackson_MV5BM2VhNGNhMGYtOWViNS00M2E5LWI2ZDgtMDJlMjI5NzhlZDNkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154664
# Image Chris_Hemsworth_MV5BOGVmYTM4MmMtOTkxYS00NjA4LTlhNDAtNzUzZmM4ZmU0YTYyXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Mark_Ruffalo_MV5BYTMwM2I0YzctZWY4NS00Y2ZjLTkzMzctYjBhNmE2ODMwNDBkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._Mark_Ruffalo_MV5BZDg0ZWUzMmQtZmViOC00ZjNmLThkZGEtM2NkZDhiNDAyYWI3XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BMjRiMTM1N2EtN2RiZS00ZmNlLWI5MzUtNjcxYTFmNmVkZGUxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BNTExNjE3MDM2OV5BMl5BanBnXkFtZTgwNjg5NzEyNTM@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BODI1YzBhY2YtODYwMC00ZTVhLTk4MDktMmNhNDZlMTU3NDdhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BYmVjZTkyMzEtN2E5Zi00NTkyLThkMTEtM2Y0N2ZhYzYxZTkwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BYzY4ZTdmYjktYWQwYS00NzY4LWI2YzUtZGJiYmFhM2U0MDAzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Robert_Downey_Jr._MV5BZjAwZWI4ZTYtOGQzNS00YTZhLWEzODQtNGUzYTQ3NGIzODcxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154756
# Image Chris_Evans_Chris_Hemsworth_MV5BYmNiNGU0OTgtNTc3OS00ODQ0LTk3NzctZDk2ZjQwY2JkMGFiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Evans_Chris_Hemsworth_MV5BZTUzMjljYmUtMWUwNS00YzgxLTgwYzYtYjNkNjUzZGNjOWFhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Evans_MV5BMmU5YTllODgtMzljNi00MjVjLTk5M2YtZmQ5Y2I2ZGUzMmYxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Evans_MV5BNjVjOWJjY2MtYzU1MS00ZTRmLWJhOTgtNDI2ZTE4NzkyYmIzXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BM2ZjZDQ3ZDQtNDA3MS00ZWEzLWEwZGUtYzU4MzI1N2FjYjY0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BMjQ0MTM1MTQ1Nl5BMl5BanBnXkFtZTgwOTk1OTU5NzM@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BMzVmYzVlOTMtYjk2ZC00Mjg3LTk3MjMtYmVjZTU5ZjU0MzNjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BODhhYzhhMzYtZmRjZC00MzNiLTk1YTMtNmU4NTU4OTM2YzBiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BOWUxZjhkMmEtMDg4ZS00MmRhLWJkZDAtZTlhOGZmY2UxMDc4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Chris_Hemsworth_MV5BZmVlYzE1NTAtMmI2Yi00ZWIxLWEyMTgtNzkzN2YxNmYwMDY0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Robert_Downey_Jr._Chris_Evans_Mark_Ruffalo_Chris_Hemsworth_MV5BN2RhMThiODQtZTM2MC00ZTRmLThkNzUtMjgzZjAzZjFhM2NiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Robert_Downey_Jr._Chris_Evans_Mark_Ruffalo_Chris_Hemsworth_MV5BY2VkNDEwNzctMDc0ZS00Mjc1LWIwNTYtZGU1YTIyYjkyMDFjXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Robert_Downey_Jr._Chris_Evans_MV5BOTY2NTYzODIxNF5BMl5BanBnXkFtZTgwMDA2OTU5NzM@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Robert_Downey_Jr._Mark_Ruffalo_Chris_Hemsworth_MV5BMjExZGZkYzQtZmRiNy00ODVkLTkxODUtY2RhYzUzZGFmNDc4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Robert_Downey_Jr._MV5BNzI2YmMyMGEtYzAyOS00OTI1LWEzODMtMjYwOWYxZDdkMWViXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4154796
# Image Luke_Grimes_MV5BMjJiODQzMTYtY2I2MC00NWE3LWI4ZGEtZDhkMWQzM2I1Nzc2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\4236770
# Image Jason_Bateman_Laura_Linney_MV5BZmU4MzI2MmMtYjc2ZS00ZGMxLWI0ZGMtOTBhOWE1YzcwYTk4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5071412
# Image Jason_Bateman_Laura_Linney_Sofia_Hublitz_Skylar_Gaertner_MV5BOWEyZmJhOWEtOTM0NS00YmYzLWI3ZmEtZDdlMWE4YTBkM2UxXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5071412
# Image Jason_Bateman_MV5BNmRlOTM0NTItMjI2Yi00NDlhLTg4NzAtYzE3OWFkNmQzMGI0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5071412
# Image Jason_Bateman_Skylar_Gaertner_MV5BNjBlNTU4MTUtOWYzZS00ZGE4LWJjODYtOWUwMWZlMGUwMjYwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5071412
# Image Rachel_Keller_Bill_Irwin_MV5BM2IyNmY3NmItM2NhMi00NTdiLWE5ODktM2E4OWRkY2VhOGQ0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5114356
# Image Leonardo_DiCaprio_MV5BMjIxMjRmNWYtNWFiMS00NjI2LTg2YjAtNTliYjExMzEwOWI4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5537002
# Image Leonardo_DiCaprio_MV5BZDM3ZTU1YWYtMmFlNy00NTc5LTg5ZTMtNzNmNTIwYzZkYWNiXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\5537002
# Image Ryan_Reynolds_Matthew_Macfadyen_MV5BNmVhNjYzMmMtOWRkYS00MzM0LTgzODctMjkyZjgwZWNmZWRkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6263850
# Image Ryan_Reynolds_MV5BMjI0ZjIzNTEtMGEzMy00NGU2LWJjMWQtMGI2M2RiYjA1MzhkXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6263850
# Image Ryan_Reynolds_MV5BNTFkOTgxYjktNTMwMy00NmRjLWE5ZDEtOTJiOTU3MmUzMjY1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6263850
# Image Ryan_Reynolds_MV5BOWRkNTAzNWMtZTUyMy00ZDgxLTgxMjktZjNlZGM3MmVmOWIwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6263850
# Image Margot_Robbie_MV5BMjk5MDdkZmMtYjg1MC00NzRhLTliMjMtZDhlN2NjMzJhM2Y5XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6334354
# Image Margot_Robbie_MV5BNTZlOGEzODEtYmZlYS00YWVmLTk3MDgtM2NkODE2Y2Y3NjZlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6334354
# Image Margot_Robbie_MV5BNWU2ZjEzNDYtYzFhYy00OGMyLTg2ZjgtY2I1YmY2ZTllZTkwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6334354
# Image Margot_Robbie_MV5BYmZlN2EyYTUtYmQzMi00NjUwLTg4ZGEtN2ZlZTIzN2I2Yjg1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6334354
# Image Charlize_Theron_Nicole_Kidman_Margot_Robbie_MV5BMjkxNTRkNGMtMWMzMy00MGVhLTkwZTUtZjhmMDgzNmI0Yjg4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\6394270
# Image Adam_Driver_MV5BOWQyOWY1YTgtNWRmNS00YzM4LWE4MTctYWE0MDU2NzIzZjU4XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\7653254
# Image Adam_Driver_MV5BYjEwYjhkODUtMDMxNi00NGMxLWFmMjAtZjEzZTQzMDg0ZmM2XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\7653254
# Image Brian_Cox_MV5BZmYwMWE1M2MtNWZjZi00ODZkLThmMzgtMjIzMmZlZGMxMmMwXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\7660850
# Image Mary_Elizabeth_Winstead_MV5BZmY1NWU0YTQtMjUxZC00YjA2LTliMWQtMzM5NTJjNjUyN2E0XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\7713068
# Image Bob_Odenkirk_Connie_Nielsen_MV5BNjMxMDU0MDctYTViZC00NWVlLWE4OGEtZjRkMDMzY2IzN2RhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\7888964
# Image Matthew_McConaughey_MV5BNzE3OTY0YzYtNmU0OC00ZjE5LTgyY2EtMDdhN2Y5ZWE3YzVhXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\8367814
# Image Matthew_McConaughey_MV5BNzM1MzA3ZTYtYTIyYS00MjMzLWE2NzUtN2NjM2QxOGYyMjRlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\8367814
# Image Owen_Wilson_Wunmi_Mosaku_MV5BNjFjOTUyYWItNjU4NS00YzcxLTg4NTYtMDZlMTk5NGFmZWZlXkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\9140554
# Image Sophia_Di_Martino_MV5BZWMwZDdmZmEtODMzMy00NTExLTgzMWMtNDcwNzlhYmI2YWI5XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\9140554
# Image Tom_Hiddleston_Owen_Wilson_MV5BYTRiZDRkZTUtNzRkMy00OGFkLTk5ZDktMGU1ZmI3ODhkZWQ5XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\9140554
# Image Tom_Hiddleston_Owen_Wilson_Sophia_Di_Martino_MV5BZWJhOTUxZjAtZjAwMi00NDAzLTkzMjMtNTNjMjdkYzRmNWU1XkEyXkFqcGc@._V1_QL75_UX2000_.jpg saved to false_image\9140554
# Accuracy: 90.19%

# %% [markdown]
# ## Đếm số lượng ảnh sai mỗi thư mục

# %%
import os


def count_images_in_folders(false_image_folder):
    # Lưu kết quả số lượng ảnh trong các thư mục con
    image_counts = {}

    # Duyệt qua tất cả các thư mục con trong thư mục false_image
    for imdb_id in os.listdir(false_image_folder):
        imdb_id_folder = os.path.join(false_image_folder, imdb_id)

        # Kiểm tra nếu là thư mục
        if os.path.isdir(imdb_id_folder):
            # Liệt kê tất cả các file ảnh trong thư mục con
            image_files = [f for f in os.listdir(imdb_id_folder) if f.lower().endswith(
                ('jpg', 'jpeg', 'png', 'gif', 'bmp'))]

            # Lưu số lượng ảnh vào dictionary
            image_counts[imdb_id] = len(image_files)

    return image_counts

# %%
false_image_folder = "false_image"  # Đường dẫn tới thư mục false_image

# Gọi hàm để liệt kê số lượng ảnh trong các thư mục
image_counts = count_images_in_folders(false_image_folder)

# In kết quả
for imdb_id, count in image_counts.items():
    print(f"IMDB ID: {imdb_id}, Number of images: {count}")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# IMDB ID: 0068646, Number of images: 5
# IMDB ID: 0120338, Number of images: 2
# IMDB ID: 0264235, Number of images: 4
# IMDB ID: 0285331, Number of images: 2
# IMDB ID: 0285333, Number of images: 5
# IMDB ID: 0367279, Number of images: 1
# IMDB ID: 0372784, Number of images: 8
# IMDB ID: 0381061, Number of images: 2
# IMDB ID: 0407887, Number of images: 6
# IMDB ID: 0468569, Number of images: 7
# IMDB ID: 0848228, Number of images: 4
# IMDB ID: 10155688, Number of images: 2
# IMDB ID: 10640346, Number of images: 3
# IMDB ID: 10648342, Number of images: 3
# IMDB ID: 1104001, Number of images: 2
# IMDB ID: 12037194, Number of images: 1
# IMDB ID: 12361974, Number of images: 2
# IMDB ID: 1345836, Number of images: 13
# IMDB ID: 1386697, Number of images: 5
# IMDB ID: 1392190, Number of images: 3
# IMDB ID: 1502407, Number of images: 3
# IMDB ID: 1517268, Number of images: 3
# IMDB ID: 1570728, Number of images: 2
# IMDB ID: 1596363, Number of images: 2
# IMDB ID: 1706620, Number of images: 2
# IMDB ID: 1707386, Number of images: 3
# IMDB ID: 1856101, Number of images: 5
# IMDB ID: 2015381, Number of images: 2
# IMDB ID: 2304589, Number of images: 1
# IMDB ID: 2356777, Number of images: 1
# IMDB ID: 2488496, Number of images: 2
# IMDB ID: 2584384, Number of images: 6
# IMDB ID: 2935510, Number of images: 2
# IMDB ID: 3032476, Number of images: 4
# IMDB ID: 3480822, Number of images: 1
# IMDB ID: 3498820, Number of images: 10
# IMDB ID: 3501632, Number of images: 12
# IMDB ID: 4154664, Number of images: 3
# IMDB ID: 4154756, Number of images: 9
# IMDB ID: 4154796, Number of images: 15
# IMDB ID: 4236770, Number of images: 1
# IMDB ID: 5071412, Number of images: 4
# IMDB ID: 5114356, Number of images: 1
# IMDB ID: 5537002, Number of images: 2
# IMDB ID: 6263850, Number of images: 4
# IMDB ID: 6334354, Number of images: 4
# IMDB ID: 6394270, Number of images: 1
# IMDB ID: 7653254, Number of images: 2
# IMDB ID: 7660850, Number of images: 1
# IMDB ID: 7713068, Number of images: 1
# IMDB ID: 7888964, Number of images: 1
# IMDB ID: 8367814, Number of images: 2
# IMDB ID: 9140554, Number of images: 4
